# %% [markdown]
# ## Description:
# > 这个情感分类项目是研一上学期选的数据挖掘项目。 此次情感分类项目的任务是给定训练集（句子和情感标签），根据所学知识训练出一个模型，然后给定测试集，测试集的每一个样例是一句话，根据模型推断所属的情感。 <br>
# > 与一般的情感分类的不同之处：
# >> * 这不是一个二分类的任务，是一个6分类的任务。
# >> * 这不是一个简单的单分类任务，而也是一个多分类任务，即一句话可能对应多个标签
# >
# > 任务分析：
# >> 基于上面的要求，这次用深度学习的模型进行尝试，做一个基于深度学习的情感分类。因为机器学习的模型的效果比较差，可能对于词向量来说，获取无法体现出句子先后的逻辑特征，所以这里采用目前最先进的自然语言处理模型-BERT，参考github(BERT_Chinese_Classification-master)，采用谷歌提供的训练好的BERT模型的接口，然后fine-tune。关于BERT的原理，可以参考GitHub(BERT_tutorial)。B站上也有视频讲的挺好的。<br>
# 任务分为下面几部分进行：
# >> * 关于BERT接口的使用，见下面的描述。这里关键是要进行数据集的准备，因为接口中的数据集要求的格式是.txt或者是.csv， 并且需要经过一些处理，所以这里主要是数据集的准备。
# >> * 关于数据集准备，训练集和测试集都需要是.txt文件，所以进行处理，并且由于目前测试集还没出来，所以在总的数据集里面分出10%作为测试集。
# >> * 划分完数据集之后，剩下的就交给BERT了，采用的环境是谷歌的colaboratory，GPU模式。
# >> * 预测完之后，结果是通过softmax预测的每个类的概率，所以，还需要转成最后提交形式的结果，这块也需要自己处理，由于可能是一个样本对应了多个标签，所以进行最终结果选择的时候，要根据概率进行筛选，如果相差不大的，就可以都写上。
# >
# >PS： 发现.txt之后的数据集效果并不是很好，所以改成了.tsv数据集，参考的一篇[博客](https://blog.csdn.net/xavier_muse/article/details/95729133)，新写了一个processor。所以后面用这个吧。

# %%
"""导入用到的两个包"""
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 处理数据集，还是和机器学习的处理一样

# %%
df = pd.read_excel('../Dataset/train.xlsx', index_col=False, names=['data','label'],encoding='utf-8')
df['data'] = df['data'].astype(str)

# %%
for d, l in df.iterrows():
    l.label = l.label.replace('[','').replace(']','').replace("'",'').split(',')

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()

# %%
for i in range(df.shape[0]):
    temp = df.iloc[i]
    if (len(temp['label'])>1):
        for item in temp['label']:
            df2 = df2.append({"data":temp['data'], "label":item.strip()}, ignore_index=True)
    else:
        df1 = df1.append(temp, ignore_index=True)

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (5364, 2)
# (1310, 2)

# %%
for i,v in df1['label'].items():
    if (type(v) == list):
        df1['label'][i] = v[0]

# %%
df = pd.concat([df1, df2], axis=0, ignore_index=True)

# %%
df.shape
# Out:
# (6674, 2)

# %%
df
# Out:
#                                                    data      label
# 0     【 恶魔们 的 高跟鞋 】 gasoline glamour shoes 集锦 ~ ~ ！ ！ ！       None
# 1     经过 长途跋涉 ， 终于 到 了 威尼斯 。 晩上 从 机场 搭乘 boat taxl ， ...  Happiness
# 2                             hello kitty 」 停 不 了 的 爱 。  Happiness
# 3     唱 错词 了 哈哈 好 可爱 坑 死 日本人 - 评论 视频 ： 1991 年 【 beyo...  Happiness
# 6671  今天 王 老爹 特别 兴奋 。 起来 的 老早 了 ， 还 在 各 个 屋子 里 晃来晃去 ...    Sadness
# 6672  时差 还 是 木 有 倒 过来 啊 。 。 。 又 困 了 。 。 。 mr. cute 已...  Happiness
# 6673  时差 还 是 木 有 倒 过来 啊 。 。 。 又 困 了 。 。 。 mr. cute 已...       Fear
#
# [6674 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# None         1896
# Happiness    1823
# Sadness      1086
# Surprise      651
# Fear          648
# Anger         570
# Name: label, dtype: int64

# %%
label_mapping = {"None": 1, "Happiness": 2, "Sadness": 3, "Surprise": 4, "Fear": 5, "Anger": 6}
df['label'] = df['label'].map(label_mapping)

# %%
df.shape
# Out:
# (6674, 2)

# %% [markdown]
# ## 划分数据集，并且写入.txt文件
# > 由于目前没有测试集，所以需要这样做，如果后面测试集来了之后，就不用划分了，只需要处理完转成.txt即可。后面我会把这个数据处理的这个写成一个函数。

# %%
x = df['data']
y = df['label']

# %%
"""划分数据集"""
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.1, random_state=8)

# %%
traintxt = pd.DataFrame({"data":X_train, "label":Y_train})
testtxt = pd.DataFrame({"data": X_test, "label": Y_test})

# %%
"""索引重置"""
traintxt.reset_index(inplace=True)
traintxt.drop('index', axis=1, inplace=True)

testtxt.reset_index(inplace=True)
testtxt.drop('index', axis=1, inplace=True)

# %%
traintxt.to_csv("BERT/data/train.txt", sep='\t')
testtxt.to_csv("BERT/data/test.txt", sep='\t')

"""这样就写入到BERT的数据集里面去了，但是还有个小问题，就是需要找到那两个.txt，打开，把首行的标签给去掉，接下来就是BERT的任务了，转入
colaboratory进行BERT模型的微调和产生结果了。具体操作，把两个.txt上传到谷歌云盘的data文件夹，然后就是运行runclassifier.py文件即可"""
# Out:
# '这样就写入到BERT的数据集里面去了，但是还有个小问题，就是需要找到那两个.txt，打开，把首行的标签给去掉，接下来就是BERT的任务了，转入\ncolaboratory进行BERT模型的微调和产生结果了。具体操作，把两个.txt上传到谷歌云盘的data文件夹，然后就是运行runclassifier.py文件即可'

# %% [markdown]
# ## 数据集准备写成一个函数
# > 这里我把上面的数据集的准备过程写成一个函数，因为目前没有测试集，才写成上面这个样子，如果测试集有了之后，就可以直接训练集和测试集分开处理写入.txt即可。 所以测试集下来之后，上面的这个过程统一使用下面这个函数进行。

# %%
import os

# %%
def DataProcess(filename):
    path = '../Dataset/'
    filepath = os.path.join(path, filename)
    
    # 测试集需要先打开，把标签那一列设置成全0
    df = pd.read_excel(filepath, index_col=False, names=['data','label'],encoding='utf-8')
    df['data'] = df['data'].astype(str)
    
    # 训练集和测试集得区分开对待, 测试集本身是对的，直接存入即可
    if filename=='train.xlsx':
        for d, l in df.iterrows():
            l.label = l.label.replace('[','').replace(']','').replace("'",'').split(',')
            
        df1 = pd.DataFrame()
        df2 = pd.DataFrame()
        
        for i in range(df.shape[0]):
            temp = df.iloc[i]
            if (len(temp['label'])>1):
                for item in temp['label']:
                    df2 = df2.append({"data":temp['data'], "label":item.strip()}, ignore_index=True)
            else:
                df1 = df1.append(temp, ignore_index=True)

        
        for i,v in df1['label'].items():
            if (type(v) == list):
                df1['label'][i] = v[0]
        
        df = pd.concat([df1, df2], axis=0, ignore_index=True)
        
        label_mapping = {"None": 1, "Happiness": 2, "Sadness": 3, "Surprise": 4, "Fear": 5, "Anger": 6}
        df['label'] = df['label'].map(label_mapping)
        df.to_csv("BERT/data/train1.txt", sep='\t')
        
    else: 
        df.to_csv("BERT/data/test.txt", sep='\t')

# %%
"""调用函数进行数据集准备"""
DataProcess('train.xlsx')
#DataProcess('test.xlsx')

# %% [markdown]
# ## 准备.tsv数据集
# > 我发现.txt数据集不太稳定， 所以根据一个[博客](https://blog.csdn.net/xavier_muse/article/details/95729133)，准备了.tsv数据集，原标签也没有变。
# >.tsv数据集类似.csv数据集，只不过用tab进行分割
# > 这里调换一下顺序，读入原训练集文件之后，第一列是label，第二列是句子，然后写入.tsv文件中

# %%
"""导入用到的两个包"""
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel('../Dataset/train.xlsx', index_col=False, names=['data','label'],encoding='utf-8')
df['data'] = df['data'].astype(str)

# %%
for d, l in df.iterrows():
     l.label = l.label.replace('[','').replace(']','').replace("'",'').split(',')
            
df1 = pd.DataFrame()
df2 = pd.DataFrame()
        
for i in range(df.shape[0]):
    temp = df.iloc[i]
    if (len(temp['label'])>1):
         for item in temp['label']:
            df2 = df2.append({"data":temp['data'], "label":item.strip()}, ignore_index=True)
    else:
            df1 = df1.append(temp, ignore_index=True)

        
for i,v in df1['label'].items():
     if (type(v) == list):
        df1['label'][i] = v[0]
        
df = pd.concat([df1, df2], axis=0, ignore_index=True)

# %%
df
# Out:
#                                                    data      label
# 0     【 恶魔们 的 高跟鞋 】 gasoline glamour shoes 集锦 ~ ~ ！ ！ ！       None
# 1     经过 长途跋涉 ， 终于 到 了 威尼斯 。 晩上 从 机场 搭乘 boat taxl ， ...  Happiness
# 2                             hello kitty 」 停 不 了 的 爱 。  Happiness
# 3     唱 错词 了 哈哈 好 可爱 坑 死 日本人 - 评论 视频 ： 1991 年 【 beyo...  Happiness
# 4     我 是 能量 满 分 选手 ， 我们 又 聊到 这么 晚 才 回家 ， 但是 如果 还 有 ...  Happiness
# 5     kelly clarkson长 得 太 肥 了 ， 她 照 镜子 的 时候 应该 在 安慰 ...       None
# 6     在 看 《 绯闻 女孩 第五 季 》 ： 是 不 是 太 久 没 看 美剧 了 ， 连 go...   Surprise
# 7     当 我 看到 “ jane love ” 这个 名字 ， 当 我 看到 那 一 句 俗气 的...      Anger
# 8     真心 觉得 iu 的 每 首 歌 都 差 不 多 啊 ~ ~ 最近 大发 的 你 和 我 也...       None
# 9     年29 大家 都 团团 圆圆 吃 团年 饭 咯 ， 天气 骤降 ， 冷冷 的 才 有 新年 ...  Happiness
# 10    定来 定 去 ， 终于 决定 要 去 hk & macau ~ 弄 了 半天 还 得 攒足 ...       None
# 11    当 你们 早 已 睡 得 跟 死猪 一样 时 ， 我 ， 一 个 人 在 外游荡 。 原 以...       Fear
# 12    下 了 班 店 里 还 分 礼物 ， 回到 家 就 收到 老姐 的 红包 happy new...  Happiness
# 6653  和 同事 结束 happy time ， 跌跌 撞撞 走 出ktv ， 己经 凌晨 了 ， ...       Fear
# 6654                               shit ! 开始 塞车 了 。 。 。    Sadness
# 6655                               shit ! 开始 塞车 了 。 。 。      Anger
# 6656  今晚 ， 发生 左 一 件 爆炸性 事件 。 刚才 ， 部 洗衣机 系度 窄 我 件 羽绒 ...  Happiness
# 6657  今晚 ， 发生 左 一 件 爆炸性 事件 。 刚才 ， 部 洗衣机 系度 窄 我 件 羽绒 ...   Surprise
# 6658  擦 ！ 坑 爹 了 么 ！ 酒留 少 了 。 。 。 日 ！ 就 不 行 ！ ！ ！ itu...  Happiness
# 6659  擦 ！ 坑 爹 了 么 ！ 酒留 少 了 。 。 。 日 ！ 就 不 行 ！ ！ ！ itu...      Anger
# 6660  happy ending 一 周年 ...110 天 成就 了 amazing couple...  Happiness
# 6661  happy ending 一 周年 ...110 天 成就 了 amazing couple...   Surprise
# 6662  我 在 听 这 张 专辑 《 wild blessed freedom 》 -carolin...  Happiness
# 6663  我 在 听 这 张 专辑 《 wild blessed freedom 》 -carolin...   Surprise
# 6664  老爸 老妈 非常 猛 ！ 纹身 都 走 起来 ！ 这个 年 过 的 非常 rock ！ 电视...  Happiness
# 6665  老爸 老妈 非常 猛 ！ 纹身 都 走 起来 ！ 这个 年 过 的 非常 rock ！ 电视...       Fear
# 6666  囧~~近 排对 着 电脑 太 多 ， 黑 眼圈 眼袋 虾米 东东 都 跑 出来 了 ， 伤 ...  Happiness
# 6667  囧~~近 排对 着 电脑 太 多 ， 黑 眼圈 眼袋 虾米 东东 都 跑 出来 了 ， 伤 ...    Sadness
# 6668  梦见 自己 在 为 四 班 的 娃 讲课 ， 还有 家长 在 听 ， 讲 的 是 “ wha...    Sadness
# 6669  梦见 自己 在 为 四 班 的 娃 讲课 ， 还有 家长 在 听 ， 讲 的 是 “ wha...   Surprise
# 6670  今天 王 老爹 特别 兴奋 。 起来 的 老早 了 ， 还 在 各 个 屋子 里 晃来晃去 ...  Happiness
# 6671  今天 王 老爹 特别 兴奋 。 起来 的 老早 了 ， 还 在 各 个 屋子 里 晃来晃去 ...    Sadness
# 6672  时差 还 是 木 有 倒 过来 啊 。 。 。 又 困 了 。 。 。 mr. cute 已...  Happiness
# 6673  时差 还 是 木 有 倒 过来 啊 。 。 。 又 困 了 。 。 。 mr. cute 已...       Fear
#
# [6674 rows x 2 columns]

# %%
label = df['label']
df.drop(['label'], axis=1, inplace=True)
df.insert(0, 'label', label)

# %%
df = shuffle(df, random_state=8)

# %%
df
# Out:
#           label                                               data
# 132   Happiness  爸爸 又 在 看 潮剧 了 ， 每 年 的 初一 总 免不了 跟着 听上 一 段 潮剧 。 ...
# 368        None  长假 过 得 差不多 了 ， 明天 大多数 人 就 要 正常 的 上班 生活 ， 发开 门利...
# 5675   Surprise  2012年 的 除夕 ， 我们 在 为 美国 的 eli 准备 生日 。 这边 的 生日 风...
# 6561   Surprise  回 老家 途中 无聊 直 到 把 i phone 玩到 没 电 还 没有 到 家 ， 突然 ...
# 2033  Happiness  3.well done ! 这个 年 没有 白 过 ， 公德 一 件 。 人情如斯 ， 时间...
# 1364    Sadness  一辈子 有 多少 真心话 是 以 玩笑 的 方式 说 了 出去 。 。 。 我 又 想起 你...
# 4547  Happiness  apple care 太 好 了 ， 三 年 前 在 伦敦 用 学生 折扣 买 的 才 一千...
#
# [6674 rows x 2 columns]

# %%
x = df['data']
y = df['label']

# %%
"""划分数据集"""
x_train, x_dev, y_train, y_dev = train_test_split(x, y, test_size=0.2, random_state=8)

traintsv = pd.DataFrame({"label":y_train, "data":x_train})
devtsv = pd.DataFrame({"label":y_dev, "data": x_dev})

# %%
"""索引重置"""
traintsv.reset_index(inplace=True)
traintsv.drop('index', axis=1, inplace=True)

devtsv.reset_index(inplace=True)
devtsv.drop('index', axis=1, inplace=True)

# %%
traintsv.to_csv("BERT/data/train.tsv", sep='\t', index=False)
devtsv.to_csv("BERT/data/dev.tsv", sep='\t', index=False)

# %% [markdown]
# ##  结果生成
# > 这一块是针对BERT对测试集返回的结果进行一个处理，生成最后要求上交的结果。BERT返回的结果是一个tsv文件，里面是每个测试样本对应的各种情感的概率，要做的就是选出概率比较大的几个作为这个样本的训练结果，比如，如果有大于90%的，那么就返回一个标签， 如果有两个差不多的，就返回两个标签等。然后做成老师要求的格式。

# %%
"""读取tsv文件，在BERT/result/result.tsv"""
res = pd.read_csv("./BERT/result/test_results .tsv", sep='\t', header=0)
res.columns
# Out:
# Index(['1', '2', '3', '4', '5', '6'], dtype='object')

# %%
# 建立映射字典
label_mapping = {'1':"None", '2':"Happiness", '3':"Sadness", '4':"Surprise", '5':"Fear", '6':'Anger' }

# %%
"""生成结果, 由于测试集没到，所以这里先用index代替每个样本"""
# 遍历res的每一行的每一列，如果大于20%， 就算这个样本的结果
result = {}
res_array = res.values   # 转成二维矩阵
for i in range(res_array.shape[0]):
    label = []
    for j in range(res_array.shape[1]):
        if (res_array[i][j]>0.2):
            label.append(label_mapping[str(j+1)])
    result[str(i)] = label

# %%
for index in result.keys():
    result[index] = ','.join(result[index])

# %%
result
# Out:
# {'0': 'Happiness',
#  '1': 'Happiness,Sadness',
#  '2': 'Happiness,Sadness',
#  '3': 'Sadness',
#  '4': 'Happiness',
#  '5': 'Happiness',
#  '6': 'Sadness',
#  '7': 'Happiness',
#  '8': 'None',
#  '9': 'None',
#  '10': 'Anger',
#  '11': 'Happiness',
#  '12': 'None',
#  '13': 'Anger',
#  '14': 'Happiness,Surprise',
#  '15': 'Sadness',
#  '16': 'None',
#  '17': 'Sadness',
#  '18': 'None',
#  '19': 'Sadness,Fear',
#  '20': 'Sadness',
#  '21': 'Happiness',
#  '22': 'None',
#  '23': 'Sadness',
#  '24': 'Happiness,Sadness',
#  '25': 'None',
#  '26': 'Happiness',
#  '27': 'None,Happiness',
#  '28': 'Happiness',
#  '29': 'Sadness',
#  '30': 'Happiness',
#  '31': 'None',
#  '32': 'Surprise,Fear',
#  '33': 'Surprise',
#  '34': 'None',
#  '35': 'None,Sadness',
#  '36': 'None,Happiness',
#  '37': 'Happiness',
#  '38': 'None',
#  '39': 'Happiness',
#  '40': 'Sadness,Fear',
#  '41': 'Fear',
#  '42': 'None',
#  '43': 'None',
#  '44': 'Happiness',
#  '45': 'Anger',
#  '46': 'None',
#  '47': 'None',
#  '48': 'Happiness',
#  '49': 'Sadness',
#  '50': 'None',
#  '51': 'None',
#  '52': 'Happiness',
#  '53': 'Sadness',
#  '54': 'Sadness',
#  '55': 'Happiness',
#  '56': 'Happiness',
#  '57': 'None',
#  '58': 'Happiness',
#  '59': 'None',
#  '60': 'Sadness',
#  '61': 'None,Sadness',
#  '62': 'Happiness',
#  '63': 'Sadness',
#  '64': 'Surprise',
#  '65': 'None',
#  '66': 'Happiness,Sadness',
#  '67': 'Happiness',
#  '68': 'Surprise,Fear',
#  '69': 'None',
#  '70': 'None',
#  '71': 'Sadness,Fear',
#  '72': 'Surprise',
#  '73': 'Happiness,Surprise',
#  '74': 'Sadness,Fear',
#  '75': 'Happiness,Sadness',
#  '76': 'Sadness,Fear',
#  '77': 'None',
#  '78': 'Happiness,Sadness',
#  '79': 'Surprise',
#  '80': 'Happiness,Sadness',
#  '81': 'Happiness',
#  '82': 'Sadness,Fear',
#  '83': 'Happiness',
#  '84': 'Sadness',
#  '85': 'Happiness',
#  '86': 'None',
#  '87': 'Sadness',
#  '88': 'Sadness',
#  '89': 'Happiness',
#  '90': 'None',
#  '91': 'Happiness,Sadness,Fear',
#  '92': 'None',
#  '93': 'Happiness',
#  '94': 'Happiness,Fear',
#  '95': 'None,Happiness',
#  '96': 'Sadness',
#  '97': 'None',
#  '98': 'Happiness',
#  '99': 'Sadness,Anger',
#  '100': 'None',
#  '101': 'Anger',
#  '102': 'Happiness',
#  '103': 'Happiness,Surprise',
#  '104': 'Sadness,Surprise,Fear',
#  '105': 'None,Sadness',
#  '106': 'Sadness',
#  '107': 'None',
#  '108': 'Happiness',
#  '109': 'Happiness',
#  '110': 'Sadness,Fear',
#  '111': 'Surprise',
#  '112': 'Sadness',
#  '113': 'None',
#  '114': 'None',
#  '115': 'Happiness',
#  '116': 'Happiness',
#  '117': 'Happiness',
#  '118': 'Happiness',
#  '119': 'None,Fear',
#  '120': 'None',
#  '121': 'Happiness',
#  '122': 'Happiness',
#  '123': 'Happiness,Sadness',
#  '124': 'Surprise',
#  '125': 'Sadness',
#  '126': 'Sadness',
#  '127': 'Happiness',
#  '128': 'None',
#  '129': 'Surprise,Fear',
#  '130': 'Anger',
#  '131': 'None',
#  '132': 'Happiness',
#  '133': 'Sadness',
#  '134': 'None,Sadness',
#  '135': 'Anger',
#  '136': 'Happiness',
#  '137': 'Happiness',
#  '138': 'None',
#  '139': 'Surprise',
#  '140': 'Happiness',
#  '141': 'Happiness',
#  '142': 'Sadness,Fear',
#  '143': 'None',
#  '144': 'Sadness,Fear',
#  '145': 'Fear',
#  '146': 'Happiness',
#  '147': 'Happiness',
#  '148': 'Sadness',
#  '149': 'Happiness,Sadness',
#  '150': 'Happiness',
#  '151': 'None',
#  '152': 'Surprise,Fear',
#  '153': 'None,Fear',
#  '154': 'Sadness,Fear',
#  '155': 'Surprise',
#  '156': 'None',
#  '157': 'Happiness,Surprise',
#  '158': 'Fear',
#  '159': 'None',
#  '160': 'None',
#  '161': 'None',
#  '162': 'Anger',
#  '163': 'None',
#  '164': 'None',
#  '165': 'Happiness',
#  '166': 'None',
#  '167': 'Happiness',
#  '168': 'Happiness',
#  '169': 'Sadness,Fear',
#  '170': 'None,Fear',
#  '171': 'Sadness',
#  '172': 'Happiness',
#  '173': 'Anger',
#  '174': 'Sadness',
#  '175': 'Sadness',
#  '176': 'Happiness,Sadness',
#  '177': 'None,Sadness',
#  '178': 'Happiness,Sadness,Anger',
#  '179': 'None',
#  '180': 'Anger',
#  '181': 'None',
#  '182': 'Anger',
#  '183': 'Surprise',
#  '184': 'None',
#  '185': 'Anger',
#  '186': 'Sadness,Fear',
#  '187': 'None,Happiness',
#  '188': 'Sadness',
#  '189': 'None,Happiness',
#  '190': 'None',
#  '191': 'Sadness',
#  '192': 'Sadness',
#  '193': 'None,Surprise',
#  '194': 'None,Fear',
#  '195': 'Sadness',
#  '196': 'Happiness',
#  '197': 'Sadness,Fear',
#  '198': 'None',
#  '199': 'Fear',
#  '200': 'Sadness,Fear',
#  '201': 'Surprise',
#  '202': 'None',
#  '203': 'None',
#  '204': 'None',
#  '205': 'Surprise',
#  '206': 'Happiness',
#  '207': 'Sadness,Fear',
#  '208': 'Anger',
#  '209': 'Happiness',
#  '210': 'Anger',
#  '211': 'Happiness',
#  '212': 'None',
#  '213': 'Sadness',
#  '214': 'Surprise,Fear',
#  '215': 'Sadness',
#  '216': 'Sadness',
#  '217': 'Sadness',
#  '218': 'Sadness,Anger',
#  '219': 'None',
#  '220': 'None',
#  '221': 'None',
#  '222': 'None,Happiness',
#  '223': 'Anger',
#  '224': 'Happiness',
#  '225': 'Sadness',
#  '226': 'Happiness',
#  '227': 'None',
#  '228': 'Happiness,Sadness',
#  '229': 'None,Happiness',
#  '230': 'None,Happiness',
#  '231': 'Surprise,Fear',
#  '232': 'None',
#  '233': 'Sadness,Fear',
#  '234': 'None',
#  '235': 'Surprise',
#  '236': 'None',
#  '237': 'None',
#  '238': 'Happiness',
#  '239': 'Happiness',
#  '240': 'None,Sadness',
#  '241': 'None',
#  '242': 'None',
#  '243': 'Sadness',
#  '244': 'Happiness',
#  '245': 'Fear',
#  '246': 'Sadness',
#  '247': 'Happiness,Sadness',
#  '248': 'Fear',
#  '249': 'Sadness',
#  '250': 'None',
#  '251': 'None,Sadness',
#  '252': 'None',
#  '253': 'Sadness',
#  '254': 'Sadness',
#  '255': 'Happiness',
#  '256': 'Surprise',
#  '257': 'None',
#  '258': 'None',
#  '259': 'Happiness',
#  '260': 'Surprise',
#  '261': 'None',
#  '262': 'Anger',
#  '263': 'None',
#  '264': 'Happiness',
#  '265': 'Happiness',
#  '266': 'Happiness,Surprise',
#  '267': 'Surprise',
#  '268': 'Happiness,Sadness',
#  '269': 'Happiness,Surprise',
#  '270': 'Happiness,Surprise',
#  '271': 'None',
#  '272': 'None',
#  '273': 'None',
#  '274': 'Happiness',
#  '275': 'Sadness,Fear',
#  '276': 'None',
#  '277': 'None',
#  '278': 'Sadness,Fear',
#  '279': 'Happiness',
#  '280': 'None',
#  '281': 'Fear',
#  '282': 'Sadness',
#  '283': 'None',
#  '284': 'None',
#  '285': 'None',
#  '286': 'None',
#  '287': 'Happiness',
#  '288': 'Sadness',
#  '289': 'Sadness',
#  '290': 'Sadness',
#  '291': 'Sadness',
#  '292': 'None',
#  '293': 'Sadness',
#  '294': 'Sadness',
#  '295': 'Sadness',
#  '296': 'None',
#  '297': 'None',
#  '298': 'Happiness',
#  '299': 'Happiness',
#  '300': 'None',
#  '301': 'Surprise',
#  '302': 'None',
#  '303': 'Happiness',
#  '304': 'Sadness',
#  '305': 'Sadness,Fear',
#  '306': 'Happiness',
#  '307': 'None',
#  '308': 'Sadness,Fear',
#  '309': 'Sadness,Anger',
#  '310': 'Sadness,Fear',
#  '311': 'Sadness,Fear',
#  '312': 'Surprise',
#  '313': 'Happiness',
#  '314': 'Sadness',
#  '315': 'Sadness,Anger',
#  '316': 'None',
#  '317': 'Happiness',
#  '318': 'None',
#  '319': 'None',
#  '320': 'None',
#  '321': 'Happiness,Sadness',
#  '322': 'Anger',
#  '323': 'None',
#  '324': 'Fear',
#  '325': 'Surprise,Fear',
#  '326': 'None',
#  '327': 'Happiness',
#  '328': 'Sadness,Fear',
#  '329': 'Anger',
#  '330': 'Sadness',
#  '331': 'Sadness',
#  '332': 'Happiness,Fear',
#  '333': 'Happiness',
#  '334': 'None',
#  '335': 'Happiness',
#  '336': 'Sadness,Fear',
#  '337': 'Sadness',
#  '338': 'Happiness',
#  '339': 'Happiness',
#  '340': 'None',
#  '341': 'None',
#  '342': 'Surprise,Fear',
#  '343': 'Surprise,Fear',
#  '344': 'None,Sadness',
#  '345': 'None',
#  '346': 'Sadness,Fear',
#  '347': 'Happiness',
#  '348': 'Anger',
#  '349': 'Sadness',
#  '350': 'None,Happiness,Sadness',
#  '351': 'Happiness',
#  '352': 'Happiness',
#  '353': 'Sadness',
#  '354': 'Surprise',
#  '355': 'Anger',
#  '356': 'Happiness',
#  '357': 'Surprise',
#  '358': 'None',
#  '359': 'None',
#  '360': 'Anger',
#  '361': 'Happiness,Sadness',
#  '362': 'Surprise,Anger',
#  '363': 'None',
#  '364': 'None,Fear',
#  '365': 'Happiness',
#  '366': 'Surprise',
#  '367': 'Sadness',
#  '368': 'None',
#  '369': 'Sadness',
#  '370': 'None,Surprise',
#  '371': 'None',
#  '372': 'None',
#  '373': 'Happiness',
#  '374': 'None',
#  '375': 'Happiness',
#  '376': 'Sadness,Fear',
#  '377': 'Surprise',
#  '378': 'Sadness',
#  '379': 'Happiness',
#  '380': 'Sadness,Fear',
#  '381': 'None',
#  '382': 'None',
#  '383': 'None',
#  '384': 'Anger',
#  '385': 'Anger',
#  '386': 'Sadness,Fear',
#  '387': 'Happiness,Surprise',
#  '388': 'Happiness',
#  '389': 'Sadness',
#  '390': 'Happiness',
#  '391': 'Happiness',
#  '392': 'None',
#  '393': 'None',
#  '394': 'None',
#  '395': 'Happiness',
#  '396': 'Happiness',
#  '397': 'None',
#  '398': 'Anger',
#  '399': 'Sadness',
#  '400': 'None,Happiness',
#  '401': 'Happiness',
#  '402': 'None',
#  '403': 'Anger',
#  '404': 'Happiness',
#  '405': 'None',
#  '406': 'Happiness',
#  '407': 'Fear',
#  '408': 'None',
#  '409': 'None',
#  '410': 'None,Sadness',
#  '411': 'Sadness,Fear',
#  '412': 'None',
#  '413': 'Sadness,Fear,Anger',
#  '414': 'Happiness',
#  '415': 'Sadness',
#  '416': 'Happiness',
#  '417': 'Happiness',
#  '418': 'None',
#  '419': 'Happiness',
#  '420': 'Sadness,Fear',
#  '421': 'Anger',
#  '422': 'Happiness',
#  '423': 'Happiness',
#  '424': 'None,Surprise',
#  '425': 'None,Happiness',
#  '426': 'Happiness',
#  '427': 'Sadness',
#  '428': 'Sadness,Fear',
#  '429': 'Happiness',
#  '430': 'Sadness',
#  '431': 'Happiness',
#  '432': 'None',
#  '433': 'Sadness,Fear',
#  '434': 'None',
#  '435': 'Surprise,Fear',
#  '436': 'Happiness',
#  '437': 'Anger',
#  '438': 'Sadness,Fear',
#  '439': 'None',
#  '440': 'Sadness,Fear',
#  '441': 'None',
#  '442': 'Sadness',
#  '443': 'None',
#  '444': 'None,Happiness',
#  '445': 'None',
#  '446': 'Happiness',
#  '447': 'None',
#  '448': 'None,Happiness',
#  '449': 'Sadness',
#  '450': 'Sadness',
#  '451': 'None',
#  '452': 'Happiness,Sadness',
#  '453': 'Happiness',
#  '454': 'Surprise',
#  '455': 'Happiness',
#  '456': 'None,Happiness',
#  '457': 'Sadness',
#  '458': 'None',
#  '459': 'Sadness,Anger',
#  '460': 'Happiness',
#  '461': 'Anger',
#  '462': 'None,Surprise,Fear',
#  '463': 'Sadness',
#  '464': 'Surprise',
#  '465': 'Surprise,Fear',
#  '466': 'Happiness',
#  '467': 'Happiness',
#  '468': 'Sadness',
#  '469': 'Happiness',
#  '470': 'Surprise',
#  '471': 'None',
#  '472': 'None,Surprise',
#  '473': 'None',
#  '474': 'None',
#  '475': 'None',
#  '476': 'Happiness',
#  '477': 'Sadness',
#  '478': 'Happiness',
#  '479': 'Happiness,Surprise',
#  '480': 'Happiness',
#  '481': 'Anger',
#  '482': 'None,Happiness',
#  '483': 'Happiness',
#  '484': 'Surprise',
#  '485': 'Happiness,Sadness',
#  '486': 'None',
#  '487': 'Happiness',
#  '488': 'None',
#  '489': 'Happiness',
#  '490': 'Happiness',
#  '491': 'Happiness,Sadness',
#  '492': 'Sadness',
#  '493': 'None',
#  '494': 'None',
#  '495': 'Happiness,Sadness',
#  '496': 'None',
#  '497': 'Happiness',
#  '498': 'Sadness',
#  '499': 'Sadness,Fear',
#  '500': 'Sadness,Fear',
#  '501': 'Anger',
#  '502': 'Sadness',
#  '503': 'Fear',
#  '504': 'Fear',
#  '505': 'Fear',
#  '506': 'Sadness',
#  '507': 'None,Fear',
#  '508': 'Happiness,Sadness',
#  '509': 'None',
#  '510': 'Happiness',
#  '511': 'Sadness,Fear',
#  '512': 'Sadness',
#  '513': 'Happiness',
#  '514': 'Happiness',
#  '515': 'Happiness',
#  '516': 'Surprise',
#  '517': 'Sadness,Fear',
#  '518': 'Anger',
#  '519': 'Sadness',
#  '520': 'Anger',
#  '521': 'Sadness,Fear',
#  '522': 'None',
#  '523': 'None',
#  '524': 'Happiness',
#  '525': 'Sadness',
#  '526': 'Happiness',
#  '527': 'None',
#  '528': 'Anger',
#  '529': 'None',
#  '530': 'None',
#  '531': 'None',
#  '532': 'Sadness',
#  '533': 'Fear',
#  '534': 'Happiness,Sadness',
#  '535': 'Happiness',
#  '536': 'Happiness',
#  '537': 'Sadness,Fear',
#  '538': 'Sadness,Fear',
#  '539': 'None',
#  '540': 'None',
#  '541': 'None',
#  '542': 'Happiness,Sadness',
#  '543': 'None',
#  '544': 'None',
#  '545': 'Sadness,Fear',
#  '546': 'Anger',
#  '547': 'Happiness',
#  '548': 'Happiness',
#  '549': 'Fear',
#  '550': 'Happiness',
#  '551': 'Sadness,Anger',
#  '552': 'Happiness,Sadness',
#  '553': 'Happiness',
#  '554': 'Happiness',
#  '555': 'None',
#  '556': 'None,Happiness',
#  '557': 'None',
#  '558': 'None',
#  '559': 'None',
#  '560': 'None',
#  '561': 'None',
#  '562': 'None',
#  '563': 'None',
#  '564': 'Happiness',
#  '565': 'Happiness',
#  '566': 'Surprise',
#  '567': 'Happiness',
#  '568': 'Happiness',
#  '569': 'None',
#  '570': 'Happiness',
#  '571': 'Fear',
#  '572': 'Happiness',
#  '573': 'Surprise,Fear',
#  '574': 'Happiness',
#  '575': 'Happiness,Sadness',
#  '576': 'None,Sadness',
#  '577': 'Anger',
#  '578': 'Anger',
#  '579': 'Surprise',
#  '580': 'Sadness,Fear,Anger',
#  '581': 'Sadness',
#  '582': 'Fear',
#  '583': 'Happiness',
#  '584': 'Happiness,Sadness',
#  '585': 'Sadness',
#  '586': 'Sadness',
#  '587': 'Happiness',
#  '588': 'Happiness',
#  '589': 'Happiness',
#  '590': 'Surprise',
#  '591': 'Happiness,Surprise',
#  '592': 'None',
#  '593': 'Happiness',
#  '594': 'Fear',
#  '595': 'None',
#  '596': 'Anger',
#  '597': 'None',
#  '598': 'None',
#  '599': 'Sadness',
#  '600': 'Happiness',
#  '601': 'Sadness,Anger',
#  '602': 'None,Happiness',
#  '603': 'Happiness,Sadness',
#  '604': 'None',
#  '605': 'Happiness',
#  '606': 'None,Happiness',
#  '607': 'Sadness',
#  '608': 'Sadness,Fear',
#  '609': 'Happiness',
#  '610': 'Sadness,Fear',
#  '611': 'Sadness,Fear',
#  '612': 'None',
#  '613': 'Happiness',
#  '614': 'Happiness',
#  '615': 'Happiness,Sadness',
#  '616': 'Sadness,Anger',
#  '617': 'None',
#  '618': 'Happiness,Sadness',
#  '619': 'None',
#  '620': 'Happiness',
#  '621': 'Happiness',
#  '622': 'Anger',
#  '623': 'None',
#  '624': 'Surprise',
#  '625': 'Happiness',
#  '626': 'None',
#  '627': 'Sadness',
#  '628': 'Sadness',
#  '629': 'Happiness',
#  '630': 'Sadness,Fear',
#  '631': 'None',
#  '632': 'None',
#  '633': 'Sadness,Fear',
#  '634': 'None',
#  '635': 'None',
#  '636': 'None,Happiness',
#  '637': 'Sadness',
#  '638': 'Happiness',
#  '639': 'Happiness,Sadness',
#  '640': 'None,Happiness',
#  '641': 'Sadness',
#  '642': 'Sadness',
#  '643': 'Happiness',
#  '644': 'Happiness,Sadness',
#  '645': 'None,Sadness,Fear',
#  '646': 'Happiness,Sadness',
#  '647': 'Happiness',
#  '648': 'Happiness',
#  '649': 'Anger',
#  '650': 'None',
#  '651': 'Happiness,Sadness,Fear',
#  '652': 'None',
#  '653': 'Happiness',
#  '654': 'Surprise',
#  '655': 'Anger',
#  '656': 'Sadness',
#  '657': 'None,Happiness',
#  '658': 'Happiness',
#  '659': 'Sadness',
#  '660': 'Fear',
#  '661': 'Happiness,Surprise',
#  '662': 'Anger',
#  '663': 'Surprise,Anger',
#  '664': 'Happiness',
#  '665': 'Sadness',
#  '666': 'Surprise,Fear',
#  '667': 'Surprise'}

# %%
list1 = []
list2 = []
for i in result.keys():
    list1.append(i)
    list2.append(result[i])

dictionary = {"id":list1, "labels": list2}

# %%
last_res = pd.DataFrame(dictionary)

# %%
"""测试集来了之后，把id这一列换成句子即可"""
last_res
# Out:
#       id                  labels
# 0      0               Happiness
# 1      1       Happiness,Sadness
# 2      2       Happiness,Sadness
# 3      3                 Sadness
# 4      4               Happiness
# 5      5               Happiness
# 6      6                 Sadness
# 7      7               Happiness
# 8      8                    None
# 9      9                    None
# 10    10                   Anger
# 11    11               Happiness
# 12    12                    None
# 13    13                   Anger
# 14    14      Happiness,Surprise
# 15    15                 Sadness
# 16    16                    None
# 17    17                 Sadness
# 18    18                    None
# 19    19            Sadness,Fear
# 20    20                 Sadness
# 21    21               Happiness
# 22    22                    None
# 23    23                 Sadness
# 24    24       Happiness,Sadness
# 25    25                    None
# 26    26               Happiness
# 27    27          None,Happiness
# 28    28               Happiness
# 29    29                 Sadness
# ..   ...                     ...
# 638  638               Happiness
# 639  639       Happiness,Sadness
# 640  640          None,Happiness
# 641  641                 Sadness
# 642  642                 Sadness
# 643  643               Happiness
# 644  644       Happiness,Sadness
# 645  645       None,Sadness,Fear
# 646  646       Happiness,Sadness
# 647  647               Happiness
# 648  648               Happiness
# 649  649                   Anger
# 650  650                    None
# 651  651  Happiness,Sadness,Fear
# 652  652                    None
# 653  653               Happiness
# 654  654                Surprise
# 655  655                   Anger
# 656  656                 Sadness
# 657  657          None,Happiness
# 658  658               Happiness
# 659  659                 Sadness
# 660  660                    Fear
# 661  661      Happiness,Surprise
# 662  662                   Anger
# 663  663          Surprise,Anger
# 664  664               Happiness
# 665  665                 Sadness
# 666  666           Surprise,Fear
# 667  667                Surprise
#
# [668 rows x 2 columns]

# %%
"""保存到文件"""
last_res.to_excel("../result/result.xlsx")

# %% [markdown]
# 参考博客：https://blog.csdn.net/xavier_muse/article/details/95729133
